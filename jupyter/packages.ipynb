# %%
# importing matplotlib module
from matplotlib import pyplot as plt
# %matplotlib inline
# x-axis values
x = [1, 2, 3, 4, 5]

# Y-axis values
y = [10, 5, 8, 4, 2]

# Function to plot
plt.plot(x, y)

# function to show the plot
plt.show()
